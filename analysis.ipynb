# %%
import pandas as pd

# %%
pd.read_json("data/cdnfinder_ans.json",orient="columns").T
# Out:
#                                                                         0  \
# google.com              {'basecdn': 'Google', 'assetcdn': 'Google', 'e...
# facebook.com            {'basecdn': None, 'assetcdn': None, 'everythin...
# amazonaws.com           {'basecdn': None, 'assetcdn': 'Amazon Cloudfro...
# microsoft.com           {'basecdn': 'Akamai', 'assetcdn': 'Akamai', 'e...
# a-msedge.net                                        {'status': 'FAILURE'}
# ...                                                                   ...
# vuasex.co                                           {'status': 'FAILURE'}
# turfomania.fr                                       {'status': 'FAILURE'}
# banglachotikahinii.com  {'basecdn': None, 'assetcdn': None, 'everythin...
# playsport.cc            {'basecdn': None, 'assetcdn': None, 'everythin...
# dnsv2.com               {'basecdn': None, 'assetcdn': None, 'everythin...
#
#                                                                         1 2   \
# ...
